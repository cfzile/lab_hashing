# %% [markdown]
# <br>

# %% [markdown]
# # Лабораторная работа #1
# <em>Построение идеальной хеш-таблицы (без коллизий)</em>

# %% [markdown]
# <br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_style("whitegrid")

idealHashing_results_int = pd.read_csv('results/idealHashing/int.out', sep=';', index_col=False)
twoTieredApproach_results_int = pd.read_csv('results/twoTieredApproach/int.out', sep=';', index_col=False)
graphHashing_results_int = pd.read_csv('results/graphHashing/int.out', sep=';', index_col=False)
idealHashing_results_string = pd.read_csv('results/idealHashing/string.out', sep=';', index_col=False)
twoTieredApproach_results_string = pd.read_csv('results/twoTieredApproach/string.out', sep=';', index_col=False)
graphHashing_results_string = pd.read_csv('results/graphHashing/string.out', sep=';', index_col=False)

# %%
idealHashing_results_int
# Out:
#     p  size  hashing time  average search time  processed memory
# 0   1   100          49.0              0.03000              96.0
# 1   1   500         998.2              0.03400            1984.8
# 2   1  1000        3894.4              0.03560            7947.2
# 3   1  2000       15128.4              0.04870           31744.0
# 4   1  5000       94275.6              0.06008          198368.0
# 5   2   100          92.8              0.03000             160.0
# 6   2   500        1814.6              0.03400            3969.6
# 7   2  1000        7319.8              0.03960           15876.0
# 8   2  2000       28710.6              0.04900           63484.0
# 9   2  5000      177417.0              0.06724          396732.0
# 10  3   100         117.0              0.03000             236.0
# 11  3   500        2699.6              0.03440            5937.6
# 12  3  1000       10782.4              0.04040           23808.0
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ## 1)Квадратичный подход к построению идеальной хеш-таблицы

# %% [markdown]
# ###  Зависимости при фиксированном размере входных данных

# %% [markdown]
# #### Зависимость времени построения от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="hashing time", hue="size", col="size",
               data=idealHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="hashing time", hue="size", col="size",
               data=idealHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость затраченной памяти от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="processed memory", hue="size", col="size",
               data=idealHashing_results_int, height=3, aspect=1, order=2)

# %%
g = sns.lmplot(x="p", y="processed memory", hue="size", col="size",
               data=idealHashing_results_string, height=3, aspect=1, order=2)

# %% [markdown]
# #### Зависимость среднего времени поиска от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="average search time", hue="size", col="size",
               data=idealHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="average search time", hue="size", col="size",
               data=idealHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# ###  Зависимости от размеров входных данных (p = const)

# %% [markdown]
# #### Зависимость времени построения от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="hashing time", hue="p", col="p",
               data=idealHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="hashing time", hue="p", col="p",
               data=idealHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость затраченной памяти от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="processed memory", hue="p", col="p",
               data=idealHashing_results_int, height=3, aspect=1, order=2)

# %%
g = sns.lmplot(x="size", y="processed memory", hue="p", col="p",
               data=idealHashing_results_string, height=3, aspect=1, order=2)

# %% [markdown]
# #### Зависимость среднего времени поиска от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="average search time", hue="p", col="p",
               data=idealHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="average search time", hue="p", col="p",
               data=idealHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# ## 2)Двух-уровневый подход к построению идеальной хеш-таблицы

# %% [markdown]
# ###  Зависимости при фиксированном размере входных данных

# %% [markdown]
# #### Зависимость времени построения от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="hashing time", hue="size", col="size",
               data=twoTieredApproach_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="hashing time", hue="size", col="size",
               data=twoTieredApproach_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость затраченной памяти от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="processed memory", hue="size", col="size",
               data=twoTieredApproach_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="processed memory", hue="size", col="size",
               data=twoTieredApproach_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость среднего времени поиска от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="average search time", hue="size", col="size",
               data=twoTieredApproach_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="average search time", hue="size", col="size",
               data=twoTieredApproach_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# ###  Зависимости от размеров входных данных (p = const)

# %% [markdown]
# #### Зависемость времени построения от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="hashing time", hue="p", col="p",
               data=twoTieredApproach_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="hashing time", hue="p", col="p",
               data=twoTieredApproach_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость затраченной памяти от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="processed memory", hue="p", col="p",
               data=twoTieredApproach_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="processed memory", hue="p", col="p",
               data=twoTieredApproach_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость среднего времени поиска от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="average search time", hue="p", col="p",
               data=twoTieredApproach_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="average search time", hue="p", col="p",
               data=twoTieredApproach_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# ## 3)Графовый подход к построению идеальной хеш-таблицы

# %% [markdown]
# ###  Зависимости при фиксированном размере входных данных

# %% [markdown]
# #### Зависимость времени построения от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="hashing time", hue="size", col="size",
               data=graphHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="hashing time", hue="size", col="size",
               data=graphHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость затраченной памяти от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="processed memory", hue="size", col="size",
               data=graphHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="processed memory", hue="size", col="size",
               data=graphHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость среднего времени поиска от размера хэш таблицы

# %%
g = sns.lmplot(x="p", y="average search time", hue="size", col="size",
               data=graphHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="p", y="average search time", hue="size", col="size",
               data=graphHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# ###  Зависимости от размеров входных данных (p = const)

# %% [markdown]
# #### Зависимость времени построения от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="hashing time", hue="p", col="p",
               data=graphHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="hashing time", hue="p", col="p",
               data=graphHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость затраченной памяти от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="processed memory", hue="p", col="p",
               data=graphHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="processed memory", hue="p", col="p",
               data=graphHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# #### Зависимость среднего времени поиска от размера хэш таблицы

# %%
g = sns.lmplot(x="size", y="average search time", hue="p", col="p",
               data=graphHashing_results_int, height=3, aspect=1, order=1)

# %%
g = sns.lmplot(x="size", y="average search time", hue="p", col="p",
               data=graphHashing_results_string, height=3, aspect=1, order=1)

# %% [markdown]
# ## Сравнение

# %%
def getMinValues(results, col_name, sizes):
    min_values = []
    for size in sizes:
        table = results[results['size'] == size]
        min_value = table[col_name].min()
        min_values.append(min_value)
    return min_values

# %%
def draw(col_name, arr1, arr2, arr3, sizes=None):
    
    if sizes is None:
        sizes = idealHashing_results_int['size'].unique()

    min_search_values_idealHashing = getMinValues(arr1, col_name, sizes)
    min_search_values_twoTieredApproach = getMinValues(arr2, col_name, sizes)
    min_search_values_graphHashing = getMinValues(arr3, col_name, sizes)
    
    df = pd.DataFrame([min_search_values_idealHashing,
                       min_search_values_twoTieredApproach,
                       min_search_values_graphHashing],
                      index=['Ideal Hashing', 'Two tiered approach', 'Graph hashing'],
                      columns=sizes).T

    plt.figure(figsize=(20, 10))
    g = sns.lineplot(data=df, markers=True, dashes=False, linewidth=5, markersize=10)
    g.tick_params(labelsize=16)
    g.set_xlabel("Data size",fontsize=16)
    g.set_ylabel(col_name,fontsize=16)
    plt.setp(g.get_legend().get_texts(), fontsize='16')
    plt.show()

# %% [markdown]
# ### Время хеширования

# %%
draw('hashing time', idealHashing_results_int, twoTieredApproach_results_int, graphHashing_results_int)

# %%
draw('hashing time',
     idealHashing_results_string,
     twoTieredApproach_results_string,
     graphHashing_results_string)

# %% [markdown]
# ### Память

# %%
draw('average search time', idealHashing_results_int, twoTieredApproach_results_int, graphHashing_results_int)

# %%
draw('average search time',
     idealHashing_results_string,
     twoTieredApproach_results_string,
     graphHashing_results_string)

# %% [markdown]
# ### Время поиска

# %%
draw("processed memory", idealHashing_results_int, twoTieredApproach_results_int, graphHashing_results_int)

# %%
draw("processed memory",
     idealHashing_results_string,
     twoTieredApproach_results_string,
     graphHashing_results_string)

# %% [markdown]
# <br>
